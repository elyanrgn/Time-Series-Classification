# %% [markdown]
# # Train IndPatchTSTClassifier

# %%
import importlib.util
from pathlib import Path
import sys

# Fallback: if package not installed in this kernel, add repo root to sys.path
if importlib.util.find_spec('src') is None:
    ROOT = Path('..').resolve()
    if str(ROOT) not in sys.path:
        sys.path.insert(0, str(ROOT))

# %% [markdown]
# **Prerequisite:** install the package in editable mode from the repo root:
#
# ```bash
# pip install -e .
# ```

# %%
from src.training.adapting_to_classification import (
    run_statistics,
    print_statistics,
    load_run_configs,
)

# Charge les configs YAML si elles existent (sinon valeurs par defaut)
load_run_configs(config_dir='configs')

# 15 runs statistiques (seed=0..14). Peut prendre du temps.
all_results = run_statistics(n_runs=15, base_seed=0)
summary = print_statistics(all_results, baseline=0.546)
# Out:
# ############################################################
#   RUN 1/15 (seed=0)
# ############################################################
#
# ───────────────────────────────────────────────────────
#   Stratégie : From Scratch (baseline)
# ───────────────────────────────────────────────────────
#   ✅ 9 patches | window=36 patch=10 stride=3
#   ⚡ From scratch (aucun poids pré-entraîné)
#
#   ▶ Entraînement (60 epochs)
#   [Full Fine-tune] 541,902/541,902 (100.0%) params entraînables
#     Epoch 01/60 | TrL=2.2447 TrA=0.314 | VlL=2.1312 VlA=0.364
#     Epoch 02/60 | TrL=2.0983 TrA=0.383 | VlL=2.0822 VlA=0.378
#     Epoch 03/60 | TrL=2.0543 TrA=0.364 | VlL=1.9707 VlA=0.411
#     Epoch 04/60 | TrL=1.9704 TrA=0.409 | VlL=1.8963 VlA=0.431
#     Epoch 05/60 | TrL=1.9344 TrA=0.414 | VlL=1.8318 VlA=0.427
#     Epoch 06/60 | TrL=1.9070 TrA=0.429 | VlL=1.8967 VlA=0.439
#     Epoch 07/60 | TrL=1.8652 TrA=0.456 | VlL=1.8452 VlA=0.409
#     Epoch 08/60 | TrL=1.8389 TrA=0.447 | VlL=1.8014 VlA=0.457
#     Epoch 09/60 | TrL=1.7909 TrA=0.480 | VlL=1.7636 VlA=0.480
#     Epoch 10/60 | TrL=1.7687 TrA=0.488 | VlL=1.7349 VlA=0.492
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 11
#       8 load_run_configs(config_dir='configs')
#      10 # 15 runs statistiques (seed=0..14). Peut prendre du temps.
# ---> 11 all_results = run_statistics(n_runs=15, base_seed=0)
#      12 summary = print_statistics(all_results, baseline=0.546)
#
# File ~\Desktop\M2DS\S2\Deep Leaning for Time series\Labs\Time-Series-Classification\src\training\adapting_to_classification.py:313, in run_statistics(n_runs, base_seed)
#     310 device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
#     312 # ── Les 4 stratégies TST avec leurs hyperparams fixes ─────────────────
# --> 313 run_results = run_single_experiment(
#     314     seed=seed,
#     315     train_dl=train_dl,
#     316     val_dl=val_dl,
#     317     test_dl=test_dl,
#     318     n_classes=n_classes,
#     319     n_features=n_features,
#     320     LSST_WINDOW=LSST_WINDOW,
#     321     device=device,
#     322     scaler_amp=torch.amp.GradScaler(enabled=device.type == "cuda"),
#     323     backbone_config=backbone_cfg,
#     324     scratch_config=scratch_cfg,
#     325     params_head_only=params_head_only,
#     326     params_late_enc=params_late_enc,
#     327     params_full_tune=params_full_tune,
#     328     best_scratch_params=best_scratch_train_params,
#     329 )
#     331 # ── Stockage des résultats par stratégie ──────────────────────────────
#     332 for key, metrics in run_results.items():
#
# File ~\Desktop\M2DS\S2\Deep Leaning for Time series\Labs\Time-Series-Classification\src\training\adapting_to_classification.py:257, in run_single_experiment(seed, train_dl, val_dl, test_dl, backbone_config, scratch_config, params_head_only, params_late_enc, params_full_tune, best_scratch_params, n_classes, n_features, LSST_WINDOW, device, scaler_amp)
#     250     opt1 = torch.optim.AdamW(
#     251         model.parameters(),
#     252         lr=best_scratch_params["lr"],
#     253         weight_decay=best_scratch_params["weight_decay"],
#     254     )
#     256 sch1 = torch.optim.lr_scheduler.CosineAnnealingLR(opt1, T_max=n_ep)
# --> 257 train_loop(
#     258     model,
#     259     train_dl,
#     260     val_dl,
#     261     opt1,
#     262     criterion,
#     263     n_ep,
#     264     device,
#     265     scheduler=sch1,
#     266     augment=(strategy not in ("full", "scratch")),
#     267     patience=12,
#     268     scaler_amp=scaler_amp,
#     269 )
#     271 acc, f1 = evaluate(model, test_dl, device)
#     272 run_results[key] = {"label": label, "acc": acc, "f1": f1}
#
# File ~\Desktop\M2DS\S2\Deep Leaning for Time series\Labs\Time-Series-Classification\src\training\train_indpatchtst_class.py:81, in train_loop(model, train_dl, val_dl, optimizer, criterion, n_epochs, device, scheduler, augment, patience, scaler_amp)
#      78 best_state = None
#      80 for epoch in range(n_epochs):
# ---> 81     tr_loss, tr_acc = train_epoch(
#      82         model, train_dl, optimizer, criterion, device, augment, scaler_amp
#      83     )
#      84     vl_loss, vl_acc = eval_epoch(model, val_dl, criterion, device)
#      86     if scheduler:
#
# File ~\Desktop\M2DS\S2\Deep Leaning for Time series\Labs\Time-Series-Classification\src\training\train_indpatchtst_class.py:28, in train_epoch(model, dl, optimizer, criterion, device, augment, scaler_amp)
#      26     scaler_amp.update()  # met à jour le scale factor (le réduit)
#      27     continue
# ---> 28 scaler_amp.scale(loss).backward()
#      29 scaler_amp.unscale_(optimizer)
#      30 torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
#
# File c:\Users\elyan\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\_tensor.py:648, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     638 if has_torch_function_unary(self):
#     639     return handle_torch_function(
#     640         Tensor.backward,
#     641         (self,),
#    (...)    646         inputs=inputs,
#     647     )
# --> 648 torch.autograd.backward(
#     649     self, gradient, retain_graph, create_graph, inputs=inputs
#     650 )
#
# File c:\Users\elyan\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\autograd\__init__.py:353, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     348     retain_graph = create_graph
#     350 # The reason we repeat the same comment below is that
#     351 # some Python versions print out the first line of a multi-line function
#     352 # calls in the traceback and some print out the last line
# --> 353 _engine_run_backward(
#     354     tensors,
#     355     grad_tensors_,
#     356     retain_graph,
#     357     create_graph,
#     358     inputs,
#     359     allow_unreachable=True,
#     360     accumulate_grad=True,
#     361 )
#
# File c:\Users\elyan\AppData\Local\Programs\Python\Python311\Lib\site-packages\torch\autograd\graph.py:824, in _engine_run_backward(t_outputs, *args, **kwargs)
#     822     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     823 try:
# --> 824     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     825         t_outputs, *args, **kwargs
#     826     )  # Calls into the C++ engine to run the backward pass
#     827 finally:
#     828     if attach_logging_hooks:
#
# KeyboardInterrupt:
